# %% [markdown]
# # GI R4 Top 10 Reading List
# In this notebook, we will use RadQG to generate 100 MCQ and 100 short-answer (ANKI) questions from the RadioGraphics GI R4 Top 10 Reading List. We will then save these into word documents for further editing and review.

# %%
# %load_ext autoreload
# %reload_ext autoreload
# %autoreload 2

import datetime
import io
import os
import pickle
import sys

sys.path.append("../../")
from docx import Document
from docx.shared import Inches, Pt
from docx.enum.text import WD_ALIGN_PARAGRAPH
from docx.oxml.ns import qn
from docx.oxml import OxmlElement
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm
from PIL import Image
import radqg.configs as configs
from radqg.generator import Generator
from radqg.llm.openai import embed_fn as openai_embed_fn
from radqg.llm.openai import qa as openai_qa
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### Extracting the figures and text from HTML files
#
# Please download your desired articles from the RadioGraphics website as HTML files and put them in the toy_data_dir folder. Do not change the names of the files and folders when saving them from the website. Five sample articles are already provided.

# %%
# Listing all the HTML files

DATA_DIR = "/research/projects/m221279_Pouria/RadQG/data/html_articles/Top_10_GI_R4"

print("Name of the articles: \n")
for file in os.listdir(DATA_DIR):
    if file.endswith(".html"):
        print(file)
# Out:
# Name of the articles:
#
# MR Imaging Evaluation of Perianal Fistulas_ Spectrum of Imaging Features _ RadioGraphics.html
# Gallbladder Carcinoma and Its Differential Diagnosis at MRI_ What Radiologists Should Know _ RadioGraphics.html
# Imaging Features of Premalignant Biliary Lesions and Predisposing Conditions with Pathologic Correlation _ RadioGraphics.html
# CT and PET in Stomach Cancer_ Preoperative Staging and Monitoring of Response to Therapy _ RadioGraphics.html
# Chronic Pancreatitis or Pancreatic Tumor_ A Problem-solving Approach _ RadioGraphics.html
# Gastrointestinal Bleeding at CT Angiography and CT Enterography_ Imaging Atlas and Glossary of Terms _ RadioGraphics.html
# Imaging and Surgical Management of Anorectal Vaginal Fistulas _ RadioGraphics.html
# Pancreatic Neuroendocrine Neoplasms_ 2020 Update on Pathologic and Imaging Findings and Classification _ RadioGraphics.html
# Heterotopic Pancreas_ Histopathologic Features, Imaging Findings, and Complications _ RadioGraphics.html
# Liver Metastases_ Correlation between Imaging Features and Pathomolecular Environments _ RadioGraphics.html

# %% [markdown]
# ### Create a QA generator
#
# Creating the QA generator is the first step in the pipeline. In addition to the path to the directory containing the HTML files, we need to specify an embedding function (e.g., from OpenAI), and the chunk_size and chunk_overlap values that should be used for splitting the articles into chunks. The latter two could be changed in the notebook or in the `config.py` file.
#
# The next step is to setup the generator. This step will return all the article names, paths to figures detected for the articles, their captions, and also a Python sampler for selecting random figures as the source for question generation. The user can specify a word or phrase as the interested `topic` when setting up the question bank for the generator. If provided, then the QA generator will be more inclined to select figures as the source for question genenration that have haptions related to the topic. Otherwise, the generator will pick completely random figures for question generation.

# %%
# Setting up the generator

generator = Generator(
    data_dir=DATA_DIR,
    embed_fn=openai_embed_fn,
    chunk_size=configs.CHUNK_SIZE,
    chunk_overlap=configs.CHUNK_OVERLAP,
)

topic = None
article_names, figpaths, captions, sampler = generator.setup_qbank(topic)
# Out:
# The collection "20231123_123145" has been created with:
#     348 figures from 10 articles

# %% [markdown]
# ### Question Generation Pipeline

# %%
# Sampling a certain number of figures

target_question_number = 50
selected_article_names = []
selected_figpaths = []
selected_captions = []

for i in tqdm(range(target_question_number)):
    article_name, figpath, caption = generator.select_figure(
        article_names, figpaths, captions, sampler, reset_memory=False
    )
    selected_article_names.append(article_name)
    selected_figpaths.append(figpath)
    selected_captions.append(caption)

assert (
    len(selected_article_names)
    == len(selected_figpaths)
    == len(selected_captions)
    == target_question_number
)
assert len(set(selected_figpaths)) == target_question_number
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %% [markdown]
# #### Generate Questions from Figures

# %%
generated_mcqs = []
generated_saqs = []

for i, (article_name, figpath, caption) in enumerate(
    zip(selected_article_names, selected_figpaths, selected_captions)
):
    while True:
        try:
            # Multiple-choice questions

            print("\n", "*" * 50, f"Generation {i} - MCQ logs:", "*" * 50, "\n")
            print(f"Figure: {figpath}")

            time0 = datetime.datetime.now()
            (
                mcq_qa_json,
                mcq_context,
                mcq_price,
                mcq_conversation,
            ) = generator.generate_qa(
                qa_fn=openai_qa,
                article_name=article_name,
                figpath=figpath,
                caption=caption,
                type_of_question="MCQ",
                complete_return=True,
            )
            mcq_time = datetime.datetime.now() - time0
            mcq_seconds = mcq_time.total_seconds()
            generated_mcqs.append(
                [mcq_qa_json, mcq_price, mcq_seconds, mcq_conversation]
            )
            print(f"MCQ: seconds: {mcq_seconds} - price: {mcq_price}")

            # Short-answer questions

            print("\n", "*" * 50, f"Generation {i} - SAQ logs:", "*" * 50, "\n")
            print(f"Figure: {figpath}")

            (
                saq_qa_json,
                saq_context,
                saq_price,
                saq_conversation,
            ) = generator.generate_qa(
                qa_fn=openai_qa,
                article_name=article_name,
                figpath=figpath,
                caption=caption,
                type_of_question="Short-Answer",
                complete_return=True,
            )
            saq_time = datetime.datetime.now() - time0 - mcq_time
            saq_seconds = saq_time.total_seconds()
            generated_saqs.append(
                [saq_qa_json, saq_price, saq_seconds, saq_conversation]
            )
            print(f"SAQ: seconds: {saq_seconds} - price: {saq_price}")
            break
        except Exception as e:
            print(e)
            continue
# Out:
#  ************************************************** Generation 0 - MCQ logs: **************************************************
#
# Figure: /research/projects/m221279_Pouria/RadQG/data/html_articles/Top_10_GI_R4/Gallbladder Carcinoma and Its Differential Diagnosis at MRI_ What Radiologists Should Know _ RadioGraphics_files/images_medium_rg.2021200087.fig6b.gif
#
# ---------Round 1---------
#
# Radiologist output: Radiologist > Question stem:
# A 65-year-old man presents with right upper quadrant pain and weight loss. Based on the findings in Figure 6b, which of the following is the most likely diagnosis?
# Options:
# {'A': 'Gallbladder adenocarcinoma with liver invasion and extensive lymphadenopathy', 'B': 'Primary lymphoma of the gallbladder', 'C': 'Exophytic hepatocellular carcinoma', 'D': 'Pericholecystic abscess due to perforated cholecystitis', 'E': 'Metastatic liver lesion'}
# Answer:
# A
# Educationist > Status: Fail: The question stem is revealing the figure number, which should not be disclosed. Also, the question stem is not referring to the figure. Revise your question like this: A 65-year-old man presents with right upper quadrant pain and weight loss. Based on the findings in the provided figure, which of the following is the most likely diagnosis? Regenerate the ```json``` with modified question stem, and if necessary, modified options and answer. Also, your provided answer is too short. The answer must be a detailed response to the question in the "answer" key of the output `json` and it should explain why the right option is correct based on the figure caption and/or the provided context!
#
# ---------Round 2---------
#
# Radiologist output: Radiologist > Question stem:
# A 65-year-old man presents with right upper quadrant pain and weight loss. Based on the findings in the provided figure, which of the following is the most likely diagnosis?
# Options:
# {'A': 'Gallbladder adenocarcinoma with liver invasion and extensive lymphadenopathy', 'B': 'Primary lymphoma of the gallbladder', 'C': 'Exophytic hepatocellular carcinoma', 'D': 'Pericholecystic abscess due to perforated cholecystitis', 'E': 'Metastatic liver lesion'}
# Answer:
# A. Gallbladder adenocarcinoma with liver invasion and extensive lymphadenopathy. The figure shows a gallbladder mass invading the liver with extensive lymphadenopathy, which is a typical presentation of gallbladder adenocarcinoma. The patient's age, symptoms, and the presence of a gallbladder mass with liver invasion and lymphadenopathy are all consistent with this diagnosis. Primary lymphoma of the gallbladder (option B) is exceedingly rare and would typically involve the submucosa, which is not mentioned in the figure caption. Exophytic hepatocellular carcinoma (option C) and metastatic liver lesion (option E) are less likely given the specific gallbladder mass and lymphadenopathy shown in the figure. Pericholecystic abscess due to perforated cholecystitis (option D) is typically associated with acute symptoms, not the chronic to subacute symptoms seen in this patient.
# Educationist > Status: Pass: The question stem, options, and answer are all appropriate. The question stem does not disclose any specific diagnosis or imaging findings from the figure caption, and it refers to the figure without disclosing the figure number. The options and answer are all plausible and relevant to the figure and clinical scenario, and only one option is the correct answer. The question requires the examinee to deduce something from the figure, and it is not answerable without viewing the figure. The question is based on a clinical scenario that is directly related to the visual content in the figure. Good job!
# MCQ: seconds: 49.961225 - price: 0.30416999999999994
#
#  ************************************************** Generation 0 - SAQ logs: **************************************************
#
# Figure: /research/projects/m221279_Pouria/RadQG/data/html_articles/Top_10_GI_R4/Gallbladder Carcinoma and Its Differential Diagnosis at MRI_ What Radiologists Should Know _ RadioGraphics_files/images_medium_rg.2021200087.fig6b.gif
#
# ---------Round 1---------
#
# Radiologist output: Radiologist > Question stem:
# A 65-year-old man presents with right upper quadrant pain and weight loss. Given the axial T2-weighted image and early contrast-enhanced T1-weighted image showing a gallbladder mass invading the liver with extensive lymphadenopathy, what is the likely N category of his condition according to the AJCC Manual?
# Answer:
# N2
# Educationist > Status: Fail: The sentence 'Given the axial T2-weighted image and early contrast-enhanced T1-weighted image showing a gallbladder mass invading the liver with extensive lymphadenopathy' is revealing an imaging finding; This is the job of the examinee to guess the imaging findings. Revise your question like this: A 65-year-old man presents with right upper quadrant pain and weight loss. An axial T2-weighted image and early contrast-enhanced T1-weighted image are provided. Based on the imaging findings, what is the likely N category of his condition according to the AJCC Manual? Regenerate the ```json``` with modified question stem, but do not change the answer.
#
# ---------Round 2---------
#
# Radiologist output: Radiologist > Question stem:
# A 65-year-old man presents with right upper quadrant pain and weight loss. An axial T2-weighted image and early contrast-enhanced T1-weighted image are provided. Based on the imaging findings, what is the likely N category of his condition according to the AJCC Manual?
# Answer:
# N2
# Educationist > Status: Pass: The question stem and answer are correct. The question stem does not reveal any specific imaging findings and it is based on a clinical scenario. The figure is referenced without disclosing the figure number. The answer is a short phrase response. The question requires the examinee to deduce something from the figure. The question and answer are useful for an Anki flashcard. Good job!
# SAQ: seconds: 30.579243 - price: 0.25805999999999996
#
#  ************************************************** Generation 1 - MCQ logs: **************************************************
#
# Figure: /research/projects/m221279_Pouria/RadQG/data/html_articles/Top_10_GI_R4/CT and PET in Stomach Cancer_ Preoperative Staging and Monitoring of Response to Therapy _ RadioGraphics_files/images_medium_g06ja24g01e.jpeg
#
# ---------Round 1---------
#
# Radiologist output: Radiologist > Question stem:
# A 55-year-old male patient presents with persistent upper abdominal pain. A CT scan was performed and the coronal reformatted image is provided (Figure 1e). Based on the figure, which of the following best describes the tumor stage and its implications?
# Options:
# {'A': 'Stage T1 tumor with focal nontransmural enhancement', 'B': 'Stage T2 tumor with a localized, transmurally enhancing ulcerative mass without perigastric extension', 'C': 'Stage T3 tumor with gross infiltration of the perigastric fat tissue', 'D': 'Stage T4 tumor with invasion of the colon', 'E': 'Stage T4 tumor infiltrating the distal pancreatic body'}
# Answer:
# Stage T4 tumor infiltrating the distal pancreatic body. This stage represents advanced cancer with gross infiltration of adjacent organs, making surgery difficult and with massive tumor invasion there is little possibility of resection.
# Educationist > Status: Fail: The question stem is revealing the figure number. Revise your question like this: A 55-year-old male patient presents with persistent upper abdominal pain. A CT scan was performed and the coronal reformatted image is provided. Based on the figure, which of the following best describes the tumor stage and its implications? Regenerate the ```json``` with modified question stem, and if necessary, modified options and answer. Also, your provided answer is too short. The answer must be a detailed response to the question in the "answer" key of the output `json` and it should explain why the right option is correct based on the figure caption and/or the provided context!
#
# ---------Round 2---------
#
# Radiologist output: Radiologist > Question stem:
# A 55-year-old male patient presents with persistent upper abdominal pain. A CT scan was performed and the coronal reformatted image is provided. Based on the figure, which of the following best describes the tumor stage and its implications?
# Options:
# {'A': 'Stage T1 tumor with focal nontransmural enhancement in the upper body of the stomach', 'B': 'Stage T2 tumor with a localized, transmurally enhancing ulcerative mass without perigastric extension in the lower body of the stomach', 'C': 'Stage T3 tumor with gross infiltration of the perigastric fat tissue in the antrum of the stomach', 'D': 'Stage T4 tumor with invasion of the colon and accompanied by obliteration of the fat plane and thickening of the colonic wall', 'E': 'Stage T4 tumor infiltrating the distal pancreatic body'}
# Answer:
# The correct answer is E, Stage T4 tumor infiltrating the distal pancreatic body. According to the figure caption and context, a Stage T4 tumor represents advanced cancer with gross infiltration of adjacent organs. In this case, the tumor is infiltrating the distal pancreatic body. This stage of cancer makes surgery difficult due to the extensive invasion into adjacent structures. Furthermore, with massive tumor invasion, there is little possibility of resection. The other options A-D are incorrect as they do not match the findings in the provided figure. Options A and B describe earlier stages of the tumor which are limited to the gastric wall and do not show infiltration into adjacent organs. Option C describes a stage T3 tumor which shows infiltration into the perigastric fat tissue but not into adjacent organs. Option D describes a stage T4 tumor, but it describes invasion of the colon, not the distal pancreatic body as seen in the figure.
# Educationist > Status: Pass: The question stem, options, and answer are all correct. The question stem does not reveal any specific diagnosis or imaging findings, and it is based on a clinical scenario. The figure is referenced in the question without disclosing the figure number. The question is designed from the text related to the figure number in the figure caption, and the user does not need to see any other figure to be able to answer the question. The question is clear, concise, and directly related to the figure and context provided. The options are labeled as A, B, C, D, and E, and only one of these is the correct answer. The question requires the examinee to deduce something from the figure, and it is not answerable without viewing the figure. Well done!
# MCQ: seconds: 52.524978 - price: 0.33828
#
#  ************************************************** Generation 1 - SAQ logs: **************************************************
#
# Figure: /research/projects/m221279_Pouria/RadQG/data/html_articles/Top_10_GI_R4/CT and PET in Stomach Cancer_ Preoperative Staging and Monitoring of Response to Therapy _ RadioGraphics_files/images_medium_g06ja24g01e.jpeg
#
# ---------Round 1---------
#
# Radiologist output: Radiologist > Question stem:
# A 55-year-old patient presents with weight loss and abdominal pain. Based on the CT scan in figure 1e, which adjacent organ is being invaded by the stage T4 gastric tumor?
# Answer:
# Distal pancreatic body
# Educationist > Status: Fail: The sentence 'Based on the CT scan in figure 1e' is mentioning the number of the figure. You must not mention the number of figure in the question stem. Revise your question like this: A 55-year-old patient presents with weight loss and abdominal pain. Based on the CT scan provided in the figure, which adjacent organ is being invaded by the stage T4 gastric tumor? Regenerate the ```json``` with modified question stem, but do not change the answer.
#
# ---------Round 2---------
#
# Radiologist output: Radiologist > Question stem:
# A 55-year-old patient presents with weight loss and abdominal pain. Based on the CT scan provided in the figure, which adjacent organ is being invaded by the stage T4 gastric tumor?
# Answer:
# Distal pancreatic body
# Educationist > Status: Pass: The question stem and answer are correct. The question stem does not disclose any specific diagnosis or imaging findings, does not mention the figure number, and is based on a clinical scenario that is directly related to the visual content in the figure. The answer is also correct and directly answers the question. No changes are needed.
# SAQ: seconds: 22.012021 - price: 0.26411999999999997
#
#  ************************************************** Generation 2 - MCQ logs: **************************************************
#
# Figure: /research/projects/m221279_Pouria/RadQG/data/html_articles/Top_10_GI_R4/Chronic Pancreatitis or Pancreatic Tumor_ A Problem-solving Approach _ RadioGraphics_files/images_medium_rg.2019190011.fig6b.gif
#
# ---------Round 1---------
#
# Radiologist output: Radiologist > Question stem:
# A 49-year-old woman presents with abdominal pain, weight loss, nausea, and jaundice. A coronal CT image (Figure 6b) shows a dilated pancreatic duct and side branches. Based on these findings, which of the following is the most likely diagnosis?
# Options:
# {'A': 'Acute pancreatitis', 'B': 'Chronic pancreatitis', 'C': 'Pancreatic ductal adenocarcinoma (PDAC)', 'D': 'Gallstones', 'E': 'Pancreatic cyst'}
# Answer:
# C
# Educationist > Status: Fail: The question stem discloses the figure number and specific imaging findings from the figure. The figure number should not be disclosed and the specific imaging findings should be deduced by the examinee. Revise the question stem to something like: 'A 49-year-old woman presents with abdominal pain, weight loss, nausea, and jaundice. A coronal CT image of the abdomen is provided. Based on the imaging findings, which of the following is the most likely diagnosis?' Regenerate the ```json``` with the modified question stem, and if necessary, modify the options and answer. Also, your provided answer is too short. The answer must be a detailed response to the question in the "answer" key of the output `json` and it should explain why the right option is correct based on the figure caption and/or the provided context!
#
# ---------Round 2---------
#
# Radiologist output: Radiologist > Question stem:
# A 49-year-old woman presents with abdominal pain, weight loss, nausea, and jaundice. A coronal CT image of the abdomen is provided. Based on the imaging findings, which of the following is the most likely diagnosis?
# Options:
# {'A': 'Acute pancreatitis', 'B': 'Chronic pancreatitis', 'C': 'Pancreatic ductal adenocarcinoma (PDAC)', 'D': 'Gallstones', 'E': 'Pancreatic cyst'}
# Answer:
# The correct answer is C. Pancreatic ductal adenocarcinoma (PDAC). The figure shows a dilated pancreatic duct and side branches, which is seen in 80% of tumors in the head of the pancreas and in 50% of tumors in the body of the pancreas. This is a classic finding of PDAC. Additionally, the patient's clinical presentation of abdominal pain, weight loss, nausea, and jaundice commonly overlap with the patient history and risk factors of PDAC. Therefore, based on the imaging findings and the clinical presentation, the most likely diagnosis is PDAC.
# Educationist > Status: Pass: The question stem, options, and answer are all appropriate. The question stem does not disclose any specific imaging findings from the figure, and it does not mention the figure number. The options are all plausible answers, and the answer explanation is thorough and accurate. No changes are needed.
# MCQ: seconds: 36.401567 - price: 0.30426
#
#  ************************************************** Generation 2 - SAQ logs: **************************************************
#
# Figure: /research/projects/m221279_Pouria/RadQG/data/html_articles/Top_10_GI_R4/Chronic Pancreatitis or Pancreatic Tumor_ A Problem-solving Approach _ RadioGraphics_files/images_medium_rg.2019190011.fig6b.gif
#
# ---------Round 1---------
#
# Radiologist output: Radiologist > Question stem:
# Based on the findings in Figure 6b, what is the likely diagnosis for the 49-year-old woman?
# Answer:
# PDAC (Pancreatic Ductal Adenocarcinoma)
# Educationist > Status: Fail: The sentence 'Based on the findings in Figure 6b, what is the likely diagnosis for the 49-year-old woman?' is mentioning the number of the figure. You must not mention the number of figure in the question stem. Revise your question like this: 'Based on the findings in the provided figure, what is the likely diagnosis for the 49-year-old woman?' Also, the question stem is revealing the diagnosis which is not allowed. You can revise it like this: 'A 49-year-old woman presents with abdominal pain. A coronal CT image of her abdomen is provided. What is the likely diagnosis?' Regenerate the ```json``` with modified question stem, but do not change the answer.
#
# ---------Round 2---------
#
# Radiologist output: Radiologist > Question stem:
# A 49-year-old woman presents with abdominal pain. A coronal CT image of her abdomen is provided. What is the likely diagnosis?
# Answer:
# PDAC (Pancreatic Ductal Adenocarcinoma)
# Educationist > Status: Pass: The question stem and answer are correct. The question stem does not disclose any specific diagnosis or imaging findings, does not mention the figure number, and is based on a clinical scenario that is directly related to the visual content in the figure. The answer is a short phrase response that requires the examinee to deduce something from the figure. The question and answer are useful for an Anki flashcard. No changes are needed.
# SAQ: seconds: 24.886444 - price: 0.26126999999999995
#
#  ************************************************** Generation 3 - MCQ logs: **************************************************
#
# Figure: /research/projects/m221279_Pouria/RadQG/data/html_articles/Top_10_GI_R4/Gallbladder Carcinoma and Its Differential Diagnosis at MRI_ What Radiologists Should Know _ RadioGraphics_files/images_medium_rg.2021200087.fig5a.gif
#
# ---------Round 1---------
#
# Radiologist output: Radiologist > Question stem:
# A 63-year-old woman presents with an incidentally found polypoid gallbladder lesion. The axial T2-weighted image shows a 2.3-cm hypointense polypoid gallbladder lesion. Based on the figure and the context, which of the following is the most likely diagnosis?
# Options:
# {'A': 'Gallbladder metastases from melanoma', 'B': 'Acute cholecystitis', 'C': 'Gallbladder carcinoma', 'D': 'Chronic cholecystitis', 'E': 'Adenomyomatosis'}
# Answer:
# Gallbladder carcinoma
# Educationist > Status: Fail: The sentence 'The axial T2-weighted image shows a 2.3-cm hypointense polypoid gallbladder lesion' is revealing an imaging finding; This is the job of the examinee to guess the imaging findings. Revise your question like this: 'A 63-year-old woman presents with an incidentally found polypoid gallbladder lesion. An axial T2-weighted image is provided in the figure. Based on the figure and the context, which of the following is the most likely diagnosis?' Regenerate the ```json``` with modified question stem, and if needed, question options or answer. Also, your provided answer is too short. The answer must be a detailed response to the question in the "answer" key of the output `json` and it should explain why the right option is correct based on the figure caption and/or the provided context!
#
# ---------Round 2---------
#
# Radiologist output: Radiologist > Question stem:
# A 63-year-old woman presents with an incidentally found polypoid gallbladder lesion. An axial T2-weighted image is provided in the figure. Based on the figure and the context, which of the following is the most likely diagnosis?
# Options:
# {'A': 'Gallbladder metastases from melanoma', 'B': 'Acute cholecystitis', 'C': 'Gallbladder carcinoma', 'D': 'Chronic cholecystitis', 'E': 'Adenomyomatosis'}
# Answer:
# The correct answer is C, Gallbladder carcinoma. The figure caption describes a hypointense polypoid gallbladder lesion in a 63-year-old woman, which is characteristic of gallbladder carcinoma. Additionally, the context explains that gallbladder carcinoma often manifests as a polypoid lesion and can be incidentally detected at imaging studies. The other options are less likely: Gallbladder metastases from melanoma (Option A) are usually discovered only at autopsy or incidentally at imaging, but the context does not suggest a history of melanoma. Acute cholecystitis (Option B) and chronic cholecystitis (Option D) may cause symmetric wall thickening, which is not described in the figure caption. Adenomyomatosis (Option E) is a benign cause of gallbladder wall thickening, which also does not align with the figure caption.
# Educationist > Status: Pass: The question stem, options, and answer are all appropriate. The question stem does not reveal any specific diagnosis or imaging findings from the figure caption, and it is based on a clinical scenario that is directly related to the visual content in the figure. The figure is referenced in the question without disclosing the figure number. The options are clearly labeled as A, B, C, D, and E, and only one of these is the correct answer. The question requires the examinee to deduce something from the figure, and it is not answerable without viewing the figure. Good job!
# MCQ: seconds: 37.353894 - price: 0.30863999999999997
#
#  ************************************************** Generation 3 - SAQ logs: **************************************************
#
# Figure: /research/projects/m221279_Pouria/RadQG/data/html_articles/Top_10_GI_R4/Gallbladder Carcinoma and Its Differential Diagnosis at MRI_ What Radiologists Should Know _ RadioGraphics_files/images_medium_rg.2021200087.fig5a.gif
#
# ---------Round 1---------
#
# Radiologist output: Radiologist > Question stem:
# A 63-year-old woman is found to have a polypoid gallbladder lesion incidentally on an axial T2-weighted image. What characteristic of the lesion would suggest it is gallbladder carcinoma rather than a gallstone?
# Answer:
# Enhancement after contrast material administration
# Educationist > Status: Fail: The sentence 'A 63-year-old woman is found to have a polypoid gallbladder lesion incidentally on an axial T2-weighted image' is revealing an imaging finding; This is the job of the examinee to guess the imaging findings. Revise your question like this: A 63-year-old woman undergoes an axial T2-weighted imaging. What characteristic of a lesion would suggest it is gallbladder carcinoma rather than a gallstone? Regenerate the ```json``` with modified question stem, but do not change the answer.
#
# ---------Round 2---------
#
# Radiologist output: Radiologist > Question stem:
# A 63-year-old woman undergoes an axial T2-weighted imaging. What characteristic of a lesion would suggest it is gallbladder carcinoma rather than a gallstone?
# Answer:
# Enhancement after contrast material administration
# Educationist > Status: Pass: The question stem and answer are correct. The question stem does not reveal any specific diagnosis or imaging findings, does not disclose the figure number, and is based on a clinical scenario directly related to the visual content in the figure. The answer is also correct and useful for an Anki flashcard. No changes are needed.
# SAQ: seconds: 21.145413 - price: 0.24989999999999996
#
#  ************************************************** Generation 4 - MCQ logs: **************************************************
#
# Figure: /research/projects/m221279_Pouria/RadQG/data/html_articles/Top_10_GI_R4/Liver Metastases_ Correlation between Imaging Features and Pathomolecular Environments _ RadioGraphics_files/images_medium_rg.220056.fig21.gif
#
# ---------Round 1---------
#
# Radiologist output: Radiologist > Question stem:
# A 64-year-old woman with a history of mucinous adenocarcinoma of the ovary 5 years previously presents with abnormal findings on an axial portal phase CT image. The image shows an intrahepatic bile duct with diffuse thickening and multiple lymph node metastases in the hepatoduodenal ligament. Based on these findings, which type of metastasis is most likely present?
# Options:
# {'A': 'Intrahepatic tumor thrombus', 'B': 'Intraluminal metastases of the bile duct', 'C': 'Biliary epithelium metastasis', 'D': 'Extrabiliary epithelium metastases', 'E': 'Intrahepatic lymphatic invasion by tumor cells'}
# Answer:
# C: Biliary epithelium metastasis
# Educationist > Status: Fail: The question stem discloses specific imaging findings from the figure caption, which is not allowed. The question stem should not reveal that 'The image shows an intrahepatic bile duct with diffuse thickening and multiple lymph node metastases in the hepatoduodenal ligament.' Instead, you can revise the question stem to: 'A 64-year-old woman with a history of mucinous adenocarcinoma of the ovary 5 years previously presents with abnormal findings on an axial portal phase CT image. Based on the imaging findings, which type of metastasis is most likely present?' Regenerate the ```json``` with the modified question stem, and if necessary, modify the options and answer. Also, your provided answer is too short. The answer must be a detailed response to the question in the "answer" key of the output `json` and it should explain why the right option is correct based on the figure caption and/or the provided context!
#
# ---------Round 2---------
#
# Radiologist output: Radiologist > Question stem:
# A 64-year-old woman with a history of mucinous adenocarcinoma of the ovary 5 years previously presents with abnormal findings on an axial portal phase CT image. Based on the imaging findings, which type of metastasis is most likely present?
# Options:
# {'A': 'Intrahepatic tumor thrombus', 'B': 'Intraluminal metastases of the bile duct', 'C': 'Biliary epithelium metastasis', 'D': 'Extrabiliary epithelium metastases', 'E': 'Intrahepatic lymphatic invasion by tumor cells'}
# Answer:
# C: Biliary epithelium metastasis. The image likely shows a case of biliary epithelium metastasis, which is a type of biliary metastasis that involves homogeneous thickening and enhancement of the bile duct. This is often seen in patients with a history of certain types of carcinomas, such as the mucinous adenocarcinoma of the ovary in this patient. The other options are less likely based on the given patient history and the typical imaging findings associated with those conditions.
# Educationist > Status: Pass: The question stem, options, and answer are all appropriate. The question stem does not disclose any specific imaging findings from the figure caption, and it is based on a clinical scenario that is directly related to the visual content in the figure. The options are clear and concise, and only one of them is the correct answer. The answer provides a clear explanation and justification. Good job!
# MCQ: seconds: 44.693531 - price: 0.30948
#
#  ************************************************** Generation 4 - SAQ logs: **************************************************
#
# Figure: /research/projects/m221279_Pouria/RadQG/data/html_articles/Top_10_GI_R4/Liver Metastases_ Correlation between Imaging Features and Pathomolecular Environments _ RadioGraphics_files/images_medium_rg.220056.fig21.gif
#
# ---------Round 1---------
#
# Radiologist output: Radiologist > Question stem:
# A 64-year-old woman with a history of mucinous adenocarcinoma of the ovary presents for a follow-up CT scan. The scan shows an intrahepatic bile duct with diffuse thickening and multiple lymph node metastases in the hepatoduodenal ligament. What has this been clinically diagnosed as?
# Answer:
# Biliary epithelium metastasis
# Educationist > Status: Fail: The sentence 'The scan shows an intrahepatic bile duct with diffuse thickening and multiple lymph node metastases in the hepatoduodenal ligament' is revealing an imaging finding; This is the job of the examinee to guess the imaging findings. Revise your question like this: A 64-year-old woman with a history of mucinous adenocarcinoma of the ovary presents for a follow-up CT scan. Based on the imaging findings, what has this been clinically diagnosed as? Regenerate the ```json``` with modified question stem, but do not change the answer.
#
# ---------Round 2---------
#
# Radiologist output: Radiologist > Question stem:
# A 64-year-old woman with a history of mucinous adenocarcinoma of the ovary presents for a follow-up CT scan. Based on the imaging findings, what has this been clinically diagnosed as?
# Answer:
# Biliary epithelium metastasis
# Educationist > Status: Pass: The question stem and answer are correct. The question stem does not reveal any specific imaging findings and is based on a clinical scenario. The figure is referenced without disclosing the figure number. The answer is directly related to the visual content in the figure. The question requires the examinee to deduce something from the figure and is not answerable without viewing the figure. The question and answer are useful for an Anki flashcard. Good job!
# SAQ: seconds: 25.324139 - price: 0.25817999999999997
#
#  ************************************************** Generation 5 - MCQ logs: **************************************************
#
# Figure: /research/projects/m221279_Pouria/RadQG/data/html_articles/Top_10_GI_R4/MR Imaging Evaluation of Perianal Fistulas_ Spectrum of Imaging Features _ RadioGraphics_files/images_medium_115040fig03.jpeg
#
# ---------Round 1---------
#
# Radiologist output: Radiologist > Question stem:
# A 52-year-old woman presents with perianal discomfort and discharge. Based on the normal anatomy of the anal canal as shown in the figure, where would you expect to find the anal glands that could be associated with the formation of perianal fistulas?
# Options:
# {'A': 'At the level of the dentate line', 'B': 'Above the anal valves at the base of the crypts of Morgagni', 'C': 'In the distal half of the anal canal', 'D': 'In the proximal half of the anal canal', 'E': 'At the anal verge'}
# Answer:
# B: Above the anal valves at the base of the crypts of Morgagni
# Educationist > Status: Fail: Your question and options are good, but your provided answer is too short. The answer must be a detailed response to the question in the "answer" key of the output `json` and it should explain why the right option is correct based on the figure caption and/or the provided context!
#
# ---------Round 2---------
#
# Radiologist output: Radiologist > Question stem:
# A 52-year-old woman presents with perianal discomfort and discharge. Based on the normal anatomy of the anal canal as shown in the figure, where would you expect to find the anal glands that could be associated with the formation of perianal fistulas?
# Options:
# {'A': 'At the level of the dentate line', 'B': 'Above the anal valves at the base of the crypts of Morgagni', 'C': 'In the distal half of the anal canal', 'D': 'In the proximal half of the anal canal', 'E': 'At the anal verge'}
# Answer:
# The correct answer is B: Above the anal valves at the base of the crypts of Morgagni. The anal glands are branched glandular structures with a stratified columnar epithelium lining. They are evenly distributed around the circumference of the anal canal, with ducts opening into the base of the crypts of Morgagni, located above the anal valves. These glands can be associated with the formation of perianal fistulas, which could explain the patient's symptoms of perianal discomfort and discharge.
# Educationist > Status: Pass: The question is clear, concise, and directly related to the figure and context provided. The question stem does not disclose any specific diagnosis or imaging findings that are mentioned in the figure caption. The figure is referenced in the question without disclosing the figure number. The question is based on a clinical scenario that is directly related to the visual content in the figure. The options are labeled as A, B, C, D, and E, and only one of these is the correct answer. The question requires the examinee to deduce something from the figure, and it is not answerable without viewing the figure. Good job!
# MCQ: seconds: 48.975528 - price: 0.29556
#
#  ************************************************** Generation 5 - SAQ logs: **************************************************
#
# Figure: /research/projects/m221279_Pouria/RadQG/data/html_articles/Top_10_GI_R4/MR Imaging Evaluation of Perianal Fistulas_ Spectrum of Imaging Features _ RadioGraphics_files/images_medium_115040fig03.jpeg
#
# ---------Round 1---------
#
# Radiologist output: Radiologist > Question stem:
# In the context of the normal anatomy of the anal canal, where do the anal glands open into?
# Answer:
# The base of the crypts of Morgagni
# Educationist > Status: Pass: The question stem does not disclose any specific diagnosis or imaging findings mentioned in the figure caption. The figure is referenced in the question without disclosing the figure number. The question is designed from the text related to the figure number in the figure caption. The question is based on a clinical scenario that is directly related to the visual content in the figure. The question meets all the criteria: it is related to the figure and context, it requires the examinee to deduce something from the figure, and it is useful for an Anki flashcard. The question is also a fill-in-the-blank question. No changes are needed.
# SAQ: seconds: 11.896525 - price: 0.11699999999999999
#
#  ************************************************** Generation 6 - MCQ logs: **************************************************
#
# Figure: /research/projects/m221279_Pouria/RadQG/data/html_articles/Top_10_GI_R4/Liver Metastases_ Correlation between Imaging Features and Pathomolecular Environments _ RadioGraphics_files/images_medium_rg.220056.fig1.gif
#
# ---------Round 1---------
#
# Radiologist output: Radiologist > Question stem:
# A 57-year-old woman with a history of pancreatic ductal carcinoma presents with new-onset jaundice. Based on Figure 1, which of the following best describes the role of tumor exosomes in the metastatic progression of her disease?
# Options:
# {'A': 'They directly cause cell death in the primary tumor', 'B': 'They are responsible for the initial invasion of the basement membrane', 'C': 'They facilitate the transformation of hepatic stellate cells into cancer-associated fibroblasts and induce liver fibrosis', 'D': 'They prevent the extravasation of tumor cells into secondary tissues', 'E': 'They block the colonization of secondary tumor sites'}
# Answer:
# C: They facilitate the transformation of hepatic stellate cells into cancer-associated fibroblasts and induce liver fibrosis
# Educationist > Status: Fail: Your question and options are good, but your provided answer is too short. The answer must be a detailed response to the question in the "answer" key of the output `json` and it should explain why the right option is correct based on the figure caption and/or the provided context!
#
# ---------Round 2---------
#
# Radiologist output: Radiologist > Question stem:
# A 57-year-old woman with a history of pancreatic ductal carcinoma presents with new-onset jaundice. Based on Figure 1, which of the following best describes the role of tumor exosomes in the metastatic progression of her disease?
# Options:
# {'A': 'They directly cause cell death in the primary tumor', 'B': 'They are responsible for the initial invasion of the basement membrane', 'C': 'They facilitate the transformation of hepatic stellate cells into cancer-associated fibroblasts and induce liver fibrosis', 'D': 'They prevent the extravasation of tumor cells into secondary tissues', 'E': 'They block the colonization of secondary tumor sites'}
# Answer:
# C: They facilitate the transformation of hepatic stellate cells into cancer-associated fibroblasts and induce liver fibrosis. According to Figure 1, tumor exosomes derived from the primary cancer contribute to the formation of a premetastatic niche in the liver. These exosomes preferentially fuse with Kupffer cells in the liver, which in turn transform hepatic stellate cells into cancer-associated fibroblasts. This transformation process induces liver fibrosis, creating a favorable environment for the metastatic progression of the disease. The other options are not supported by the information provided in the figure and context.
# Educationist > Status: Pass: The question is well-structured and meets all the criteria. The question stem does not disclose any specific diagnosis or imaging findings mentioned in the figure caption. The figure is referenced in the question without disclosing the figure number. The question is based on a clinical scenario that is directly related to the visual content in the figure. The question is clear, concise, and directly related to the figure and context provided. It provides five options, labeled as A, B, C, D, and E, and only one of these is the correct answer. The question requires the examinee to deduce something from the figure, and it is not answerable without viewing the figure. The question is based on a clinical scenario that is directly related to the visual content in the figure. No changes are needed.
# MCQ: seconds: 45.557184 - price: 0.33453
#
#  ************************************************** Generation 6 - SAQ logs: **************************************************
#
# Figure: /research/projects/m221279_Pouria/RadQG/data/html_articles/Top_10_GI_R4/Liver Metastases_ Correlation between Imaging Features and Pathomolecular Environments _ RadioGraphics_files/images_medium_rg.220056.fig1.gif
#
# ---------Round 1---------
#
# Radiologist output: Radiologist > Question stem:
# In the context of tumor metastasis progression as depicted in Figure 1, which cells transform into cancer-associated fibroblasts and induce liver fibrosis after fusing with organ-specific exosomes effused by the primary tumor?
# Answer:
# Kupffer cells
# Educationist > Status: Fail: The question stem is referring to the figure number, which should not be disclosed. Revise your question like this: In the context of tumor metastasis progression as depicted in the provided figure, which cells transform into cancer-associated fibroblasts and induce liver fibrosis after fusing with organ-specific exosomes effused by the primary tumor? Regenerate the ```json``` with the modified question stem, but do not change the answer.
#
# ---------Round 2---------
#
# Radiologist output: Radiologist > Question stem:
# In the context of tumor metastasis progression as depicted in the provided figure, which cells transform into cancer-associated fibroblasts and induce liver fibrosis after fusing with organ-specific exosomes effused by the primary tumor?
# Answer:
# Kupffer cells
# Educationist > Status: Pass: The question stem and answer are correct. The question stem does not disclose any specific diagnosis or imaging findings from the figure caption, it does not mention the figure number, and it is based on a clinical scenario that is directly related to the visual content in the figure. The question requires the examinee to deduce something from the figure, and it is not answerable without viewing the figure. The question and answer are useful for an Anki flashcard. The question is a fill-in-the-blank question. No changes are needed.
# SAQ: seconds: 26.180832 - price: 0.27039
#
#  ************************************************** Generation 7 - MCQ logs: **************************************************
#
# Figure: /research/projects/m221279_Pouria/RadQG/data/html_articles/Top_10_GI_R4/Imaging and Surgical Management of Anorectal Vaginal Fistulas _ RadioGraphics_files/images_medium_rg.2018170167.fig16a.gif
#
# ---------Round 1---------
#
# Radiologist output: Radiologist > Question stem:
# A 45-year-old woman presents with a recurrent rectovaginal fistula. Despite multiple attempts at closure, the fistula keeps reopening. You decide to proceed with a procedure that involves the creation of a Martius flap. Based on the illustration in Figure 16a, which of the following steps correctly describes the initial part of this procedure?
# Options:
# {'A': 'An incision is made on the labium minus pudendi to expose the fat pad underneath.', 'B': 'An incision is made on the labium majus pudendi to expose the fat pad underneath.', 'C': 'A tunnel connecting the pedicle of the fat pad to the rectal opening is formed.', 'D': 'The fistula is left open, and a Martius flap is created without ligation.', 'E': 'The bulbocavernosus muscle is harvested for the creation of the Martius flap.'}
# Answer:
# B: An incision is made on the labium majus pudendi to expose the fat pad underneath.
# Educationist > Status: Fail: The question stem is revealing the figure number. Change 'Based on the illustration in Figure 16a' to 'Based on the provided illustration'. Also, the question stem is disclosing a specific imaging finding that is mentioned in the figure caption. Change 'You decide to proceed with a procedure that involves the creation of a Martius flap' to 'You decide to proceed with a procedure'. Regenerate the ```json``` with the modified question stem, and if necessary, modified options and answer. Also, your provided answer is too short. The answer must be a detailed response to the question in the "answer" key of the output `json` and it should explain why the right option is correct based on the figure caption and/or the provided context!
#
# ---------Round 2---------
#
# Radiologist output: Radiologist > Question stem:
# A 45-year-old woman presents with a recurrent rectovaginal fistula. Despite multiple attempts at closure, the fistula keeps reopening. You decide to proceed with a procedure. Based on the provided illustration, which of the following steps correctly describes the initial part of this procedure?
# Options:
# {'A': 'An incision is made on the labium minus pudendi to expose the fat pad underneath.', 'B': 'An incision is made on the labium majus pudendi to expose the fat pad underneath.', 'C': 'A tunnel connecting the pedicle of the fat pad to the rectal opening is formed.', 'D': 'The fistula is left open, and a flap is created without ligation.', 'E': 'The bulbocavernosus muscle is harvested for the creation of the flap.'}
# Answer:
# B: An incision is made on the labium majus pudendi to expose the fat pad underneath. This step is the initial part of the procedure for creating a Martius flap, as shown in the illustration. This flap is typically used in the treatment of rectovaginal fistulas, especially in cases where previous attempts at closure have been unsuccessful. The labium majus pudendi is chosen for the incision because it contains a substantial amount of fat tissue, which is necessary for the creation of the flap. The incision allows the surgeon to access this fat pad and create the flap. The other options do not accurately represent the initial steps in the creation of a Martius flap.
# Educationist > Status: Pass: The question stem, options, and answer are all correct. The question stem does not disclose any specific diagnosis or imaging findings mentioned in the figure caption. The figure is referenced in the question without disclosing the figure number. The question is based on a clinical scenario that is directly related to the visual content in the figure. The question is clear, concise, and directly related to the figure and context provided. The options are labeled as A, B, C, D, and E, and only one of these is the correct answer. The question requires the examinee to deduce something from the figure, and it is not answerable without viewing the figure. The question is based on a clinical scenario that is directly related to the visual content in the figure. No changes are needed.
# MCQ: seconds: 57.362609 - price: 0.32904
#
#  ************************************************** Generation 7 - SAQ logs: **************************************************
#
# Figure: /research/projects/m221279_Pouria/RadQG/data/html_articles/Top_10_GI_R4/Imaging and Surgical Management of Anorectal Vaginal Fistulas _ RadioGraphics_files/images_medium_rg.2018170167.fig16a.gif
#
# ---------Round 1---------
#
# Radiologist output: Radiologist > Question stem:
# In the procedure illustrated in Figure 16a, after the fistula is ligated and the Martius flap is created, what anatomical structure is the flap gently transferred through?
# Answer:
# Vaginal opening
# Educationist > Status: Fail: The sentence 'In the procedure illustrated in Figure 16a' is mentioning the number of the figure. You must not mention the number of figure in the question stem. Revise your question like this: In the procedure illustrated in the figure, after the fistula is ligated and the Martius flap is created, what anatomical structure is the flap gently transferred through? Regenerate the ```json``` with modified question stem, but do not change the answer.
#
# ---------Round 2---------
#
# Radiologist output: Radiologist > Question stem:
# In the procedure illustrated in the figure, after the fistula is ligated and the Martius flap is created, what anatomical structure is the flap gently transferred through?
# Answer:
# Vaginal opening
# Educationist > Status: Pass: The question stem and answer are correct. The question stem does not disclose any specific diagnosis or imaging findings mentioned in the figure caption, and it does not mention the figure number. The question is based on a clinical scenario that is directly related to the visual content in the figure. The question requires the examinee to deduce something from the figure, and it is not answerable without viewing the figure. The question and answer are useful for an Anki flashcard. The question is a fill-in-the-blank question. No changes are needed.
# SAQ: seconds: 20.746674 - price: 0.25629
#
#  ************************************************** Generation 8 - MCQ logs: **************************************************
#
# Figure: /research/projects/m221279_Pouria/RadQG/data/html_articles/Top_10_GI_R4/Gallbladder Carcinoma and Its Differential Diagnosis at MRI_ What Radiologists Should Know _ RadioGraphics_files/images_medium_rg.2021200087.fig11c.gif
#
# ---------Round 1---------
#
# Radiologist output: Radiologist > Question stem:
# A 53-year-old woman presents with a focal mass in the fundus of the gallbladder shown in the figure. Based on the T1-weighted image, which of the following is the most likely diagnosis?
# Options:
# {'A': 'Gallbladder carcinoma', 'B': 'Gallbladder adenomyoma', 'C': 'Primary lymphoma of the gallbladder', 'D': 'Secondary lymphoma of the gallbladder', 'E': 'Gallbladder polyp'}
# Answer:
# B: Gallbladder adenomyoma. The image shows a mass with fairly homogeneous enhancement, which is characteristic of gallbladder adenomyoma. The other options are less likely given the imaging findings and the patient's clinical context.
# Educationist > Status: Fail: The question stem discloses specific imaging findings from the figure caption, which is not allowed. The sentence 'A 53-year-old woman presents with a focal mass in the fundus of the gallbladder shown in the figure' should be revised to 'A 53-year-old woman presents with a gallbladder abnormality shown in the figure'. Also, the figure number must not be disclosed. Please regenerate the ```json``` with a modified question stem, and if necessary, modified options and answer. Also, your provided answer is too short. The answer must be a detailed response to the question in the "answer" key of the output `json` and it should explain why the right option is correct based on the figure caption and/or the provided context!
#
# ---------Round 2---------
#
# Radiologist output: Radiologist > Question stem:
# A 53-year-old woman presents with a gallbladder abnormality shown in the figure. Based on the T1-weighted image, which of the following is the most likely diagnosis?
# Options:
# {'A': 'Gallbladder carcinoma', 'B': 'Gallbladder adenomyoma', 'C': 'Primary lymphoma of the gallbladder', 'D': 'Secondary lymphoma of the gallbladder', 'E': 'Gallbladder polyp'}
# Answer:
# ...
# Answer:
# C: Acute Diverticular Bleed in the Sigmoid Colon
# Educationist > Status: Fail: The question stem is referring to a specific figure number, which should not be disclosed. Instead, refer to the figure in a general way, such as 'the provided figure' or 'the figure above'. Also, the question stem is revealing the patient's age which is a specific detail from the figure caption. Please revise the question stem to something like: 'A patient presents with bright red blood in the rectum. A CT image is provided. Based on the imaging findings, which of the following is the most likely diagnosis?' Regenerate the ```json``` with the modified question stem, and if necessary, modified options and answer. Also, your provided answer is too short. The answer must be a detailed response to the question in the "answer" key of the output `json` and it should explain why the right option is correct based on the figure caption and/or the provided context!
#
# ---------Round 2---------
#
# Radiologist output: Radiologist > Question stem:
# A patient presents with bright red blood in the rectum. A CT image is provided. Based on the imaging findings, which of the following is the most likely diagnosis?
# Options:
# {'A': 'Colonic Ischemia', 'B': 'Anorectal Disease', 'C': 'Acute Diverticular Bleed in the Sigmoid Colon', 'D': 'GI or Suspected Small Bowel Bleeding', 'E': 'Mesenteric Venous Thrombosis'}
# Answer:
# The correct answer is C: Acute Diverticular Bleed in the Sigmoid Colon. The figure shows multiple foci of contrast extravasation in the sigmoid colon and diffuse sigmoid diverticulosis, some containing extravasated contrast material. This is indicative of an acute diverticular bleed in the sigmoid colon. The other options are less likely based on the provided image and the patient's presentation. Colonic Ischemia (Option A) typically results in bowel wall thickening and pericolonic fat stranding, which is not evident in the image. Anorectal Disease (Option B) usually presents with enlarged serpiginous veins within the anus and lower rectum, which is not the case here. GI or Suspected Small Bowel Bleeding (Option D) and Mesenteric Venous Thrombosis (Option E) would not present with the specific contrast extravasation in the sigmoid colon as seen in the figure.
# Educationist > Status: Pass: The question stem, options, and answer are all appropriate. The question stem does not reveal any specific imaging findings from the figure caption, and it does not disclose the figure number. The options are all plausible, and the answer is correct and well-explained. The question is based on a clinical scenario that is directly related to the visual content in the figure. Good job!
# MCQ: seconds: 48.967341 - price: 0.31484999999999996
#
#  ************************************************** Generation 47 - SAQ logs: **************************************************
#
# Figure: /research/projects/m221279_Pouria/RadQG/data/html_articles/Top_10_GI_R4/Gastrointestinal Bleeding at CT Angiography and CT Enterography_ Imaging Atlas and Glossary of Terms _ RadioGraphics_files/images_medium_rg.2021210043.fig8.gif
#
# ---------Round 1---------
#
# Radiologist output: Radiologist > Question stem:
# A 72-year-old man presents with bright red blood in the rectum. Based on the CT images in Figure 8, what is the most likely diagnosis?
# Answer:
# Acute diverticular bleed in the sigmoid colon
# Educationist > Status: Fail: The sentence 'Based on the CT images in Figure 8, what is the most likely diagnosis?' is mentioning the number of the figure. You must not mention the number of figure in the question stem. Revise your question like this: A 72-year-old man presents with bright red blood in the rectum. Based on the CT images provided in the figure, what is the most likely diagnosis? Regenerate the ```json``` with modified question stem, but do not change the answer.
#
# ---------Round 2---------
#
# Radiologist output: Radiologist > Question stem:
# A 72-year-old man presents with bright red blood in the rectum. Based on the CT images provided in the figure, what is the most likely diagnosis?
# Answer:
# Acute diverticular bleed in the sigmoid colon
# Educationist > Status: Pass: The question stem and answer are correct. The question stem does not disclose any specific diagnosis or imaging findings mentioned in the figure caption, and it does not mention the figure number. The question is based on a clinical scenario that is directly related to the visual content in the figure. The question requires the examinee to deduce something from the figure, and it is not answerable without viewing the figure. The question and answer are useful for an Anki flashcard. Good job! No need to regenerate the ```json```.
# SAQ: seconds: 19.883749 - price: 0.25844999999999996
#
#  ************************************************** Generation 48 - MCQ logs: **************************************************
#
# Figure: /research/projects/m221279_Pouria/RadQG/data/html_articles/Top_10_GI_R4/Heterotopic Pancreas_ Histopathologic Features, Imaging Findings, and Complications _ RadioGraphics_files/images_medium_rg.2017160091.fig11b.gif
#
# ---------Round 1---------
#
# Radiologist output: Radiologist > Question stem:
# A 38-year-old woman presents with abdominal pain and discomfort. A contrast-enhanced CT scan is performed and reveals an intramural mass along the greater curvature of the gastric antrum. The mass is intensely enhancing and contains multiple small internal cystic areas. The overlying gastric mucosa is also hyperenhanced. Based on these findings, what is the most likely diagnosis?
# Options:
# {'A': 'Gastric carcinoma', 'B': 'Gastric pancreatic heterotopia complicated by pseudocyst formation', 'C': 'Gastric lymphoma', 'D': 'Gastric peptic ulcer disease', 'E': 'Gastric diverticulum'}
# Answer:
# Gastric pancreatic heterotopia complicated by pseudocyst formation
# Educationist > Status: Fail: The question stem discloses specific imaging findings from the figure, which should be deduced by the examinee. Revise the question stem to something like: 'A 38-year-old woman presents with abdominal pain and discomfort. A contrast-enhanced CT scan of the abdomen is provided. Based on the imaging findings, what is the most likely diagnosis?' Regenerate the ```json``` with the modified question stem, and if necessary, modify the options and answer. Also, your provided answer is too short. The answer must be a detailed response to the question in the "answer" key of the output `json` and it should explain why the right option is correct based on the figure caption and/or the provided context!
#
# ---------Round 2---------
#
# Radiologist output: Radiologist > Question stem:
# A 38-year-old woman presents with abdominal pain and discomfort. A contrast-enhanced CT scan of the abdomen is provided. Based on the imaging findings, what is the most likely diagnosis?
# Options:
# {'A': 'Gastric carcinoma', 'B': 'Gastric pancreatic heterotopia complicated by pseudocyst formation', 'C': 'Gastric lymphoma', 'D': 'Gastric peptic ulcer disease', 'E': 'Gastric diverticulum'}
# Answer:
# The correct diagnosis is B, Gastric pancreatic heterotopia complicated by pseudocyst formation. Gastric pancreatic heterotopia is a congenital anomaly where pancreatic tissue is found separate from the main gland. The CT scan shows an intramural mass along the greater curvature of the gastric antrum, which is a common location for this condition. The mass is intensely enhancing and contains multiple small internal cystic areas, a characteristic of this condition. The hyperenhancement of the overlying gastric mucosa further supports this diagnosis. The other options are less likely because they do not typically present with these specific imaging findings.
# Educationist > Status: Pass: The question stem, options, and answer are all appropriate. The question stem does not disclose any specific imaging findings from the figure, and it is based on a clinical scenario. The options are clear and concise, and only one of them is the correct answer. The answer provides a thorough explanation for why it is correct and why the other options are less likely. Good job!
# MCQ: seconds: 40.804632 - price: 0.30278999999999995
#
#  ************************************************** Generation 48 - SAQ logs: **************************************************
#
# Figure: /research/projects/m221279_Pouria/RadQG/data/html_articles/Top_10_GI_R4/Heterotopic Pancreas_ Histopathologic Features, Imaging Findings, and Complications _ RadioGraphics_files/images_medium_rg.2017160091.fig11b.gif
#
# ---------Round 1---------
#
# Radiologist output: Radiologist > Question stem:
# In the context of a 38-year-old woman with an intramural mass along the greater curvature of the gastric antrum, what congenital anomaly is suggested by the presence of intensely enhancing tissue containing multiple small internal cystic areas, as seen in Figure 11b?
# Answer:
# Heterotopic pancreas
# Educationist > Status: Fail: The question stem is revealing specific imaging findings ('an intramural mass along the greater curvature of the gastric antrum', 'intensely enhancing tissue containing multiple small internal cystic areas') which should be deduced by the examinee. Also, the figure number is mentioned in the question stem. Revise your question like this: In the context of a 38-year-old woman, the provided figure shows an intramural mass. What congenital anomaly is suggested by the imaging findings? Regenerate the ```json``` with modified question stem, but do not change the answer.
#
# ---------Round 2---------
#
# Radiologist output: Radiologist > Question stem:
# In the context of a 38-year-old woman, the provided figure shows an intramural mass. What congenital anomaly is suggested by the imaging findings?
# Answer:
# Heterotopic pancreas
# Educationist > Status: Pass: The question stem and answer are now correct. The question stem does not reveal any specific imaging findings and does not mention the figure number. The answer is also appropriate. No changes are needed.
# SAQ: seconds: 22.798832 - price: 0.25287
#
#  ************************************************** Generation 49 - MCQ logs: **************************************************
#
# Figure: /research/projects/m221279_Pouria/RadQG/data/html_articles/Top_10_GI_R4/Imaging and Surgical Management of Anorectal Vaginal Fistulas _ RadioGraphics_files/images_medium_rg.2018170167.fig9c.gif
#
# ---------Round 1---------
#
# Radiologist output: Radiologist > Question stem:
# A 57-year-old woman underwent treatment for rectal adenocarcinoma that had invaded the vagina. Post-treatment axial T2-weighted MR images (Fig 9c) show changes in her condition. What is the most likely outcome based on these images?
# Options:
# {'A': 'Complete resolution of the fistula and rectal mass', 'B': 'Persistence of the fistula with substantial loss of the right lateral and anterior rectal walls', 'C': 'Development of an anovaginal fistula', 'D': 'Complete recovery with no loss of rectal and vaginal tissue', 'E': 'Development of a colovaginal fistula due to diverticulitis'}
# Answer:
# Persistence of the fistula with substantial loss of the right lateral and anterior rectal walls
# Educationist > Status: Fail: The question stem discloses the figure number (Fig 9c), which is not allowed. Please revise the question stem to refer to the figure without disclosing its number, for example: 'A 57-year-old woman underwent treatment for rectal adenocarcinoma that had invaded the vagina. Post-treatment axial T2-weighted MR images are provided. What is the most likely outcome based on these images?' Regenerate the ```json``` with the modified question stem, and if necessary, modify the options and answer. Also, your provided answer is too short. The answer must be a detailed response to the question in the "answer" key of the output `json` and it should explain why the right option is correct based on the figure caption and/or the provided context!
#
# ---------Round 2---------
#
# Radiologist output: Radiologist > Question stem:
# A 57-year-old woman underwent treatment for rectal adenocarcinoma that had invaded the vagina. Post-treatment axial T2-weighted MR images are provided. What is the most likely outcome based on these images?
# Options:
# {'A': 'Complete resolution of the fistula and rectal mass', 'B': 'Persistence of the fistula with substantial loss of the right lateral and anterior rectal walls', 'C': 'Development of an anovaginal fistula', 'D': 'Complete recovery with no loss of rectal and vaginal tissue', 'E': 'Development of a colovaginal fistula due to diverticulitis'}
# Answer:
# The correct answer is B, 'Persistence of the fistula with substantial loss of the right lateral and anterior rectal walls'. The figure shows a marked treatment response in the tumor, however, the fistula persists, resulting in a loss of substantial portions of the right lateral and anterior rectal walls, with destruction of the vagina and right piriformis muscle. This is indicative of the aggressive nature of the disease and the extensive damage it has caused. The other options do not accurately reflect the post-treatment condition shown in the figure. Complete resolution of the fistula and rectal mass (Option A) and complete recovery with no loss of rectal and vaginal tissue (Option D) are not observed in the figure. Development of an anovaginal fistula (Option C) and a colovaginal fistula due to diverticulitis (Option E) are not mentioned in the figure caption or the context, and are therefore not relevant to the question.
# Educationist > Status: Pass: The question stem, options, and answer are all appropriate. The question stem does not disclose any specific diagnosis or imaging findings, and it does not disclose the figure number. The question is based on a clinical scenario that is directly related to the visual content in the figure. The options are clear and concise, and only one of them is the correct answer. The question requires the examinee to deduce something from the figure, and it is not answerable without viewing the figure. Well done!
# MCQ: seconds: 35.027575 - price: 0.32238
#
#  ************************************************** Generation 49 - SAQ logs: **************************************************
#
# Figure: /research/projects/m221279_Pouria/RadQG/data/html_articles/Top_10_GI_R4/Imaging and Surgical Management of Anorectal Vaginal Fistulas _ RadioGraphics_files/images_medium_rg.2018170167.fig9c.gif
#
# ---------Round 1---------
#
# Radiologist output: Radiologist > Question stem:
# In the context of the Figure 9c, what was the treatment outcome of the rectal adenocarcinoma invading the vagina?
# Answer:
# Marked treatment response
# Educationist > Status: Fail: The sentence 'In the context of the Figure 9c, what was the treatment outcome of the rectal adenocarcinoma invading the vagina?' is mentioning the number of the figure. You must not mention the number of figure in the question stem. Revise your question like like this: In the context of the provided figure, what was the treatment outcome of the rectal adenocarcinoma invading the vagina? Regenerate the ```json``` with modified question stem, but do not change the answer.
#
# ---------Round 2---------
#
# Radiologist output: Radiologist > Question stem:
# In the context of the provided figure, what was the treatment outcome of the rectal adenocarcinoma invading the vagina?
# Answer:
# Marked treatment response
# Educationist > Status: Pass: The question stem and answer meet all the criteria. The question stem does not disclose any specific diagnosis or imaging findings mentioned in the figure caption, it references the figure without disclosing the figure number, it is based on a clinical scenario directly related to the visual content in the figure, and it requires the examinee to deduce something from the figure. The answer is also appropriate. No changes are needed.
# SAQ: seconds: 18.918796 - price: 0.25466999999999995

# %%
# Saving the generated questions

with open("generated_mcqs.pkl", "wb") as f:
    pickle.dump(generated_mcqs, f)

with open("generated_saqs.pkl", "wb") as f:
    pickle.dump(generated_saqs, f)

with open("selected_article_names.pkl", "wb") as f:
    pickle.dump(selected_article_names, f)

with open("selected_figpaths.pkl", "wb") as f:
    pickle.dump(selected_figpaths, f)

with open("selected_captions.pkl", "wb") as f:
    pickle.dump(selected_captions, f)

# %% [markdown]
# ### Building the word files

# %%
with open("generated_mcqs.pkl", "rb") as f:
    generated_mcqs = pickle.load(f)

with open("generated_saqs.pkl", "rb") as f:
    generated_saqs = pickle.load(f)

with open("selected_article_names.pkl", "rb") as f:
    selected_article_names = pickle.load(f)

with open("selected_figpaths.pkl", "rb") as f:
    selected_figpaths = pickle.load(f)

with open("selected_captions.pkl", "rb") as f:
    selected_captions = pickle.load(f)

# %%
all_mcq_questions = [x[0] for x in generated_mcqs]
all_mcq_prices = [x[1] for x in generated_mcqs]
all_mcq_seconds = [x[2] for x in generated_mcqs]
all_mcq_len_conversations = [len(x[3]) - 1 for x in generated_mcqs]

print("Number of generated MCQs: ", len(all_mcq_questions))
print("Average price of MCQs: ", sum(all_mcq_prices) / len(all_mcq_prices))
print("Average time of MCQs: ", sum(all_mcq_seconds) / len(all_mcq_seconds))
print("Total price of MCQs: ", sum(all_mcq_prices))
print("Total time of MCQs (in hours): ", sum(all_mcq_seconds) / 3600)
print(
    "Average number of conversations: ",
    sum(all_mcq_len_conversations) / len(all_mcq_len_conversations),
)

all_saq_questions = [x[0] for x in generated_saqs]
all_saq_prices = [x[1] for x in generated_saqs]
all_saq_seconds = [x[2] for x in generated_saqs]
all_saq_len_conversations = [len(x[3]) - 1 for x in generated_saqs]

print("Number of generated SAQs: ", len(all_saq_questions))
print("Average price of SAQs: ", sum(all_saq_prices) / len(all_saq_prices))
print("Average time of SAQs: ", sum(all_saq_seconds) / len(all_saq_seconds))
print("Total price of SAQs: ", sum(all_saq_prices))
print("Total time of SAQs (in hours): ", sum(all_saq_seconds) / 3600)
print(
    "Average number of conversations: ",
    sum(all_saq_len_conversations) / len(all_saq_len_conversations),
)

assert (
    len(all_mcq_questions)
    == len(all_mcq_prices)
    == len(all_mcq_seconds)
    == len(all_saq_questions)
    == len(all_saq_prices)
    == len(all_saq_seconds)
    == target_question_number
)
# Out:
# Number of generated MCQs:  50
# Average price of MCQs:  0.3848165999999999
# Average time of MCQs:  51.15475182000002
# Total price of MCQs:  19.240829999999995
# Total time of MCQs (in hours):  0.7104826641666669
# Average number of conversations:  4.72
# Number of generated SAQs:  50
# Average price of SAQs:  0.25719539999999996
# Average time of SAQs:  23.130401799999994
# Total price of SAQs:  12.859769999999997
# Total time of SAQs (in hours):  0.3212555805555555
# Average number of conversations:  3.96

# %%
def create_word_file(article_names, figpaths, captions, questions, save_path, title):
    doc = Document()

    # Add title
    title_para = doc.add_paragraph(title)
    title_para.alignment = WD_ALIGN_PARAGRAPH.CENTER
    run = title_para.runs[0]
    run.font.size = Pt(14)
    run.font.bold = True

    for i, question in enumerate(questions, start=1):
        # Question
        doc.add_paragraph(f"Question {i}:", style="Heading1")
        doc.add_paragraph(question["question"])

        # Image
        if os.path.exists(figpaths[i - 1]):
            with open(figpaths[i - 1], "rb") as f:
                image_stream = io.BytesIO(f.read())
                image = Image.open(image_stream)
                image_stream = io.BytesIO()
                image.save(image_stream, format="PNG")
                doc.add_picture(image_stream, width=Inches(4))

        # Options
        if "options" in question:
            # doc.add_paragraph('Options:', style='Heading1')
            for option, text in question["options"].items():
                doc.add_paragraph(f"{option}: {text}")

        # Answer
        doc.add_paragraph("Answer:", style="Heading1")
        doc.add_paragraph(question["answer"])

        # Source and Figure Caption
        article_name = article_names[i - 1].split(" _ RadioGraphics.html")[0]
        if article_name == "":
            article_name = article_names[i - 1].split(" _ RadioGraphics.html")[1]
        doc.add_paragraph("---Source:")
        doc.add_paragraph(article_name)
        doc.add_paragraph("---Original Figure Caption:")
        doc.add_paragraph(captions[i - 1])

        # Horizontal line
        if i < len(questions):  # No line after the last question
            p = doc.add_paragraph()
            p.alignment = WD_ALIGN_PARAGRAPH.CENTER
            run = p.add_run()
            run.add_break()
            horizontal_line = OxmlElement("w:pBdr")
            bottom_border = OxmlElement("w:bottom")
            bottom_border.set(qn("w:val"), "single")
            bottom_border.set(qn("w:sz"), "6")
            bottom_border.set(qn("w:space"), "1")
            bottom_border.set(qn("w:color"), "auto")
            horizontal_line.append(bottom_border)
            p._element.get_or_add_pPr().append(horizontal_line)

    # Save the document
    doc.save(save_path)

# %%
# Save MCQ questions to Word file

create_word_file(
    article_names=selected_article_names,
    figpaths=selected_figpaths,
    captions=selected_captions,
    questions=all_mcq_questions,
    save_path="MCQs.docx",
    title="AI-Generated Multiple Choice Questions from\nRadioGraphics Top 10 Reading List\n(Gastrointestinal Imaging - R4)",
)

# Save SAQ questions to Word file
create_word_file(
    article_names=selected_article_names,
    figpaths=selected_figpaths,
    captions=selected_captions,
    questions=all_saq_questions,
    save_path="SAQs.docx",
    title="AI-Generated Short Answer Questions from\nRadioGraphics Top 10 Reading List\n(Gastrointestinal Imaging - R4)",
)
# Out:
# /research/projects/m221279_Pouria/0_Miniconda3/envs/LLM/lib/python3.11/site-packages/docx/styles/styles.py:130: UserWarning: style lookup by style_id is deprecated. Use style name as key instead.
#   return self._get_style_id_from_style(self[style_name], style_type)
